# %% [markdown]
# pandasの中でnumpy使ってる

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 2, np.nan])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
s[0]
# Out:
# 1.0

# %%
# Nanは無視
s.sum()
# Out:
# 3.0

# %%
df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %% [markdown]
# SeriesよりDataFrameを使う機会の方が多いかも？

# %%
df.dtypes
# Out:
# A    int64
# B    int64
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(6, 4))
df
# Out:
#           0         1         2         3
# 0  1.155768  3.252745 -0.657384  0.985332
# 1  0.264338  0.335066 -0.436776 -1.223975
# 2 -1.235900 -0.815657  0.002473 -0.718795
# 3  0.239991  0.375636  0.412538  1.995807
# 4  1.180916  0.655027  1.111250 -1.620931
# 5 -1.802006 -2.166106 -0.063248 -0.579985

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20170101', periods = 6))
df
# Out:
#                    0         1         2         3
# 2017-01-01  1.604110 -0.382333  0.760755 -1.348929
# 2017-01-02 -0.175061 -1.209974  0.276338  1.455801
# 2017-01-03 -1.487766 -0.705704  1.684325 -1.288761
# 2017-01-04  0.573660 -0.388279 -0.961043  0.146190
# 2017-01-05 -0.594782  0.572313 -2.151932 -0.750315
# 2017-01-06 -0.268330  0.000295 -1.991252 -0.138826

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=pd.date_range('20170101', periods = 6), columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2017-01-01 -0.856348 -0.461959 -0.180838  1.456520
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454
# 2017-01-03  0.397848 -0.429328  0.882611  0.113468
# 2017-01-04 -1.587487 -1.023203  1.749387  0.846289
# 2017-01-05 -1.698868 -1.666340 -0.718294 -0.888231
# 2017-01-06 -0.694796 -0.907028 -1.097658 -1.088137

# %%
df.head(1)
# Out:
#                    A         B         C        D
# 2017-01-01 -0.856348 -0.461959 -0.180838  1.45652

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2017-01-04 -1.587487 -1.023203  1.749387  0.846289
# 2017-01-05 -1.698868 -1.666340 -0.718294 -0.888231
# 2017-01-06 -0.694796 -0.907028 -1.097658 -1.088137

# %%
df.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.85634834, -0.46195892, -0.18083771,  1.45651981],
#        [ 0.10892374, -0.87224808, -0.48020983,  0.38145357],
#        [ 0.39784832, -0.42932791,  0.88261132,  0.11346776],
#        [-1.58748676, -1.02320308,  1.74938706,  0.84628941],
#        [-1.69886776, -1.66634001, -0.71829409, -0.8882306 ],
#        [-0.69479613, -0.90702762, -1.09765775, -1.08813742]])

# %%
# 便利だなぁと昔思った
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.721788 -0.893351  0.025833  0.136894
# std    0.856344  0.450871  1.078838  0.985555
# min   -1.698868 -1.666340 -1.097658 -1.088137
# 25%   -1.404702 -0.994159 -0.658773 -0.637806
# 50%   -0.775572 -0.889638 -0.330524  0.247461
# 75%   -0.092006 -0.564531  0.616749  0.730080
# max    0.397848 -0.429328  1.749387  1.456520

# %%
df.T
# Out:
#    2017-01-01  2017-01-02  2017-01-03  2017-01-04  2017-01-05  2017-01-06
# A   -0.856348    0.108924    0.397848   -1.587487   -1.698868   -0.694796
# B   -0.461959   -0.872248   -0.429328   -1.023203   -1.666340   -0.907028
# C   -0.180838   -0.480210    0.882611    1.749387   -0.718294   -1.097658
# D    1.456520    0.381454    0.113468    0.846289   -0.888231   -1.088137

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2017-01-05 -1.698868 -1.666340 -0.718294 -0.888231
# 2017-01-04 -1.587487 -1.023203  1.749387  0.846289
# 2017-01-06 -0.694796 -0.907028 -1.097658 -1.088137
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454
# 2017-01-01 -0.856348 -0.461959 -0.180838  1.456520
# 2017-01-03  0.397848 -0.429328  0.882611  0.113468

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2017-01-01 -0.856348 -0.461959 -0.180838  1.456520
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454
# 2017-01-03  0.397848 -0.429328  0.882611  0.113468

# %%
df['20170102':'20170104']
# Out:
#                    A         B         C         D
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454
# 2017-01-03  0.397848 -0.429328  0.882611  0.113468
# 2017-01-04 -1.587487 -1.023203  1.749387  0.846289

# %%
df.loc['20170101']
# Out:
# A   -0.856348
# B   -0.461959
# C   -0.180838
# D    1.456520
# Name: 2017-01-01 00:00:00, dtype: float64

# %%
df.loc['20170102',['A', 'B']]
# Out:
# A    0.108924
# B   -0.872248
# Name: 2017-01-02 00:00:00, dtype: float64

# %%
df.loc['20170102':'20170104',['A', 'B']]
# Out:
#                    A         B
# 2017-01-02  0.108924 -0.872248
# 2017-01-03  0.397848 -0.429328
# 2017-01-04 -1.587487 -1.023203

# %%
df.loc[:,['A', 'B']]
# Out:
#                    A         B
# 2017-01-01 -0.856348 -0.461959
# 2017-01-02  0.108924 -0.872248
# 2017-01-03  0.397848 -0.429328
# 2017-01-04 -1.587487 -1.023203
# 2017-01-05 -1.698868 -1.666340
# 2017-01-06 -0.694796 -0.907028

# %%
df.iloc[0, 0]
# Out:
# -0.8563483390336482

# %%
df.iloc[0:2, 0:2]
# Out:
#                    A         B
# 2017-01-01 -0.856348 -0.461959
# 2017-01-02  0.108924 -0.872248

# %%
df[df.A>0]
# Out:
#                    A         B         C         D
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454
# 2017-01-03  0.397848 -0.429328  0.882611  0.113468

# %%
df[df>0]
# Out:
#                    A   B         C         D
# 2017-01-01       NaN NaN       NaN  1.456520
# 2017-01-02  0.108924 NaN       NaN  0.381454
# 2017-01-03  0.397848 NaN  0.882611  0.113468
# 2017-01-04       NaN NaN  1.749387  0.846289
# 2017-01-05       NaN NaN       NaN       NaN
# 2017-01-06       NaN NaN       NaN       NaN

# %%
df
# Out:
#                    A         B         C         D
# 2017-01-01 -0.856348 -0.461959 -0.180838  1.456520
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454
# 2017-01-03  0.397848 -0.429328  0.882611  0.113468
# 2017-01-04 -1.587487 -1.023203  1.749387  0.846289
# 2017-01-05 -1.698868 -1.666340 -0.718294 -0.888231
# 2017-01-06 -0.694796 -0.907028 -1.097658 -1.088137

# %%
df2 = df.copy()
df2['E'] =['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2017-01-01 -0.856348 -0.461959 -0.180838  1.456520    one
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454    one
# 2017-01-03  0.397848 -0.429328  0.882611  0.113468    two
# 2017-01-04 -1.587487 -1.023203  1.749387  0.846289  three
# 2017-01-05 -1.698868 -1.666340 -0.718294 -0.888231   four
# 2017-01-06 -0.694796 -0.907028 -1.097658 -1.088137  three

# %%
df2[df2['E'].isin(['one', 'four'])]
# Out:
#                    A         B         C         D     E
# 2017-01-01 -0.856348 -0.461959 -0.180838  1.456520   one
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454   one
# 2017-01-05 -1.698868 -1.666340 -0.718294 -0.888231  four

# %%
df
# Out:
#                    A         B         C         D
# 2017-01-01 -0.856348 -0.461959 -0.180838  1.456520
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454
# 2017-01-03  0.397848 -0.429328  0.882611  0.113468
# 2017-01-04 -1.587487 -1.023203  1.749387  0.846289
# 2017-01-05 -1.698868 -1.666340 -0.718294 -0.888231
# 2017-01-06 -0.694796 -0.907028 -1.097658 -1.088137

# %%
s = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20170101', periods=6))
s
# Out:
# 2017-01-01    1
# 2017-01-02    2
# 2017-01-03    3
# 2017-01-04    4
# 2017-01-05    5
# 2017-01-06    6
# Freq: D, dtype: int64

# %%
df['E'] = s

# %%
df
# Out:
#                    A         B         C         D  E
# 2017-01-01 -0.856348 -0.461959 -0.180838  1.456520  1
# 2017-01-02  0.108924 -0.872248 -0.480210  0.381454  2
# 2017-01-03  0.397848 -0.429328  0.882611  0.113468  3
# 2017-01-04 -1.587487 -1.023203  1.749387  0.846289  4
# 2017-01-05 -1.698868 -1.666340 -0.718294 -0.888231  5
# 2017-01-06 -0.694796 -0.907028 -1.097658 -1.088137  6

# %%
df.shift(1)
# Out:
#                    A         B         C         D    E
# 2017-01-01       NaN       NaN       NaN       NaN  NaN
# 2017-01-02 -0.856348 -0.461959 -0.180838  1.456520  1.0
# 2017-01-03  0.108924 -0.872248 -0.480210  0.381454  2.0
# 2017-01-04  0.397848 -0.429328  0.882611  0.113468  3.0
# 2017-01-05 -1.587487 -1.023203  1.749387  0.846289  4.0
# 2017-01-06 -1.698868 -1.666340 -0.718294 -0.888231  5.0

# %%
df = pd.DataFrame(np.random.randn(2,2))
df
# Out:
#           0         1
# 0  0.320190 -0.680137
# 1 -0.162771 -0.008372

# %%
pd.concat([df,df])
# Out:
#           0         1
# 0  0.320190 -0.680137
# 1 -0.162771 -0.008372
# 0  0.320190 -0.680137
# 1 -0.162771 -0.008372

# %%
df = pd.DataFrame(np.random.rand(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.473971  0.002917  0.052282  0.261635
# 1  0.457376  0.169519  0.332611  0.044096
# 2  0.394394  0.096200  0.354921  0.140761
# 3  0.189589  0.990915  0.020941  0.195291
# 4  0.176210  0.087601  0.809816  0.168971
# 5  0.459055  0.271500  0.567932  0.054288
# 6  0.404772  0.834260  0.486837  0.925434
# 7  0.720206  0.722860  0.407164  0.536865

# %%
s = df.iloc[0]
s
# Out:
# A    0.473971
# B    0.002917
# C    0.052282
# D    0.261635
# Name: 0, dtype: float64

# %%
df.append(s)
# Out:
#           A         B         C         D
# 0  0.473971  0.002917  0.052282  0.261635
# 1  0.457376  0.169519  0.332611  0.044096
# 2  0.394394  0.096200  0.354921  0.140761
# 3  0.189589  0.990915  0.020941  0.195291
# 4  0.176210  0.087601  0.809816  0.168971
# 5  0.459055  0.271500  0.567932  0.054288
# 6  0.404772  0.834260  0.486837  0.925434
# 7  0.720206  0.722860  0.407164  0.536865
# 0  0.473971  0.002917  0.052282  0.261635

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.473971  0.002917  0.052282  0.261635
# 1  0.457376  0.169519  0.332611  0.044096
# 2  0.394394  0.096200  0.354921  0.140761
# 3  0.189589  0.990915  0.020941  0.195291
# 4  0.176210  0.087601  0.809816  0.168971
# 5  0.459055  0.271500  0.567932  0.054288
# 6  0.404772  0.834260  0.486837  0.925434
# 7  0.720206  0.722860  0.407164  0.536865
# 8  0.473971  0.002917  0.052282  0.261635

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar'], 'B' : np.random.randn(4)})

# %%
df
# Out:
#      A         B
# 0  foo  1.397077
# 1  bar -0.171825
# 2  foo  0.191213
# 3  bar  0.013646

# %%
df.groupby('A').sum()
# Out:
#             B
# A
# bar -0.158179
# foo  1.588290

# %%
# !pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading https://files.pythonhosted.org/packages/22/f1/a02eea03628865c3d4c29849cda8c8a73f43358048aee47d79dfbfa6c6c3/pandas_datareader-0.9.0-py3-none-any.whl (107kB)
#     100% |████████████████████████████████| 112kB 2.5MB/s ta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /Users/sabe/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages (from pandas_datareader) (0.23.0)
# Collecting requests>=2.19.0 (from pandas_datareader)
#   Downloading https://files.pythonhosted.org/packages/45/1e/0c169c6a5381e241ba7404532c16a21d86ab872c9bed8bdcd4c423954103/requests-2.24.0-py2.py3-none-any.whl (61kB)
#     100% |████████████████████████████████| 71kB 5.3MB/s ta 0:00:011
# Requirement already satisfied: lxml in /Users/sabe/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages (from pandas_datareader) (4.2.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/sabe/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages (from pandas>=0.23->pandas_datareader) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /Users/sabe/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages (from pandas>=0.23->pandas_datareader) (2018.4)
# Requirement already satisfied: numpy>=1.9.0 in /Users/sabe/.local/lib/python3.6/site-packages (from pandas>=0.23->pandas_datareader) (1.19.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sabe/.local/lib/python3.6/site-packages (from requests>=2.19.0->pandas_datareader) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/sabe/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages (from requests>=2.19.0->pandas_datareader) (1.22)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/sabe/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/sabe/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages (from requests>=2.19.0->pandas_datareader) (2.6)
# Requirement already satisfied: six>=1.5 in /Users/sabe/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.23->pandas_datareader) (1.11.0)
# distributed 1.21.8 requires msgpack, which is not installed.
# Installing collected packages: requests, pandas-datareader
#   Found existing installation: requests 2.18.4
#     Uninstalling requests-2.18.4:
#       Successfully uninstalled requests-2.18.4
# Successfully installed pandas-datareader-0.9.0 requests-2.24.0
# You are using pip version 10.0.1, however version 20.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pand